# %% [markdown]
#  # Data Mining with Python
#
# ## Python Basics
#
# *  [Basic Python Syntax](./python-basics/Python-Basics.ipynb)
# *  [Lists, Tuples, Sets, and Dictionaries](/Users/kivanc/DataMining/JupyterNotebooks/ipynb/python-basics/Lists-Tuples-Sets-Dictionaries.ipynb)
# *  [Functions](./python-basics/Functions.ipynb)
# *  [Namespaces and Scope](./python-basics/Namespaces-and-Scope.ipynb)
# *  [Control-Flow](./python-basics/Control-Flow.ipynb)
# *  [Modules](./python-basics/Modules.ipynb)
# *  [Classes](./python-basics/Classes.ipynb)
# *  [Exception Handling](./python-basics/Exception-Handling.ipynb)
# *  [File-IO](./python-basics/File-IO.ipynb)
# *  [Formatting-Output](./python-basics/Formatting-Output.ipynb)
#
#
# ## Toolkits: Numpy, Pandas, SciPy, Matplotlib
#
# There are a number of Python packages that are commonly used for data science and machine learning purposes.
#
# *  [Numpy](./toolkit-overviews/Numpy.ipynb)
# *  [Pandas](./toolkit-overviews/Pandas.ipynb)
# *  [Matplotlib](./toolkit-overviews/Matplotlib.ipynb)
# *  [Basic Statistics](./toolkit-overviews/statistics-intro.ipynb)
# *  [NLTK](./toolkit-overviews/NLTK.ipynb)
#
#
# ## Basic Methods and Models
#
# *  [Scikit-learn](./toolkit-overviews/Scikit-learn.ipynb)
# *  [Naive Bayes](./naive-bayes/naive-bayes-exercises.ipynb)
# *  [Examples - Text Classification with Naive Bayes](./naive-bayes/naive-bayes-examples.ipynb)
# *  [Linear Regression](./gradient-descent/linear-regression.ipynb)
# *  [Logistic Regression](./gradient-descent/logistic-regression.ipynb)
# *  [Simple Perceptrons](./neural/simple-perceptrons.ipynb)
# *  [Decision Trees](./trees/trees.ipynb)
# *  [KNN](./instance-based/instance-based-learning.ipynb)
# *  Clustering
#
# ## Evaluating Models
#
# *  [Statistics - Confidence Intervals](./evaluating-models/confidence-intervals.ipynb)
# *  [Evaluating Classifier Performance](./evaluating-models/evaluating-classifier-performance.ipynb)
# *  [Cross Validation](./evaluating-models/cross-validation.ipynb)
# *  [Classifier-Metrics](./evaluating-models/classifier-metrics.ipynb)
# *  KNN-Revisited
#
# ## More Advanced Methods
#
# *  [Multilayer Perceptrons](./neural/multilayer-perceptrons.ipynb)
# *  [Support Vector Machines](./svm/support-vector-machines.ipynb)
#
# ## Ensemble Learning
#
# *  [Ensembles](./ensembles/ensemble-methods.ipynb)
#
# ## Association Rules
#
# *  [Apriori](./apriori/apriori.ipynb)
#
# ## Miscellaneous
#
# *  [Semisupervised Learning](./semisupervised/Semisupervised.ipynb)
# *  [Bias-Variance Tradeoff](./bias-variance/bias-variance.ipynb)
